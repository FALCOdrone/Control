# %% [markdown]
# **Classical PID tuning**

# %% [markdown]
# Here below is provided a classical PID control system tuning. By implementing the allready tuned system on simulink

# %%
# !pip install --upgrade stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /Users/ortol/miniforge3/lib/python3.12/site-packages (2.5.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (2.6.0)
# Requirement already satisfied: cloudpickle in /Users/ortol/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /Users/ortol/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: matplotlib in /Users/ortol/miniforge3/lib/python3.12/site-packages (from stable-baselines3) (3.10.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /Users/ortol/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /Users/ortol/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /Users/ortol/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: setuptools in /Users/ortol/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (75.3.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from pandas->stable-baselines3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from pandas->stable-baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /Users/ortol/miniforge3/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/ortol/miniforge3/lib/python3.12/site-packages (from gymnasium) (0.0.4)

# %%
import pybullet as p
import pybullet_data
import gym
import numpy as np
from gym import spaces
import logging

class DroneClassicalEnv(gym.Env):
    def __init__(self):
        super(DroneClassicalEnv, self).__init__()

        # Connect using DIRECT mode (no GUI)
        self.physicsClient = p.connect(p.GUI)  
        if self.physicsClient < 0:
            raise ValueError("Failed to connect to PyBullet")

        p.setAdditionalSearchPath(pybullet_data.getDataPath())
        p.setGravity(0, 0, -9.8)

        # Load drone
        self.drone = p.loadURDF("/Users/ortol/Desktop/Falco/Local_Control/bullet3-master/data/Quadrotor/quadrotor.urdf", [0, 0, 0], useFixedBase=False)
        if self.drone < 0:
            raise ValueError("Failed to load drone URDF")

        self.action_space = spaces.Box(low=0, high=10, shape=(18,), dtype=np.float32) # Kp, Ki, Kd for (x, y, z), (r, p,y)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(6,), dtype=np.float32) # x, y, z, roll, pitch, yaw

        self.target_position = np.array([0, 0, 5])
        self.target_orn = np.array([0, 0, 0, 1])
        self.state = np.zeros(6) # x, y, z, roll, pitch, yaw
        self.max_torque = 2
        self.min_torque = -2
        self.torque = np.zeros(4) # 4 motors
        self.prev_error_pos = np.zeros(3)
        self.prev_error_orn = np.zeros(3)
        self.Ts = 0.01
        self.k1 = 0.001
        self.k2 = 1
        self.prev_prime_pitch_error_orn = 0 
        self.prev_prime_roll_error_orn = 0
        self.m = 3.7695
        self.g = 9.8
        self.max_thrust = 500
        self.min_thrust = -500

        # Mixer matrix for quadrotor (assuming '+' configuration)
        self.mixer_matrix = np.array([
            [1,  1,  1,  1],  # Total thrust
            [1, -1, -1,  1],  # Roll torque
            [1,  1, -1, -1],  # Pitch torque
            [1, -1,  1, -1]   # Yaw torque
        ])

    def step(self, action):
        action = np.array(action).reshape(3, 6)
        Kp = action[0][:]
        Ki = action[1][:]
        Kd = action[2][:]

        Kp_pos = Kp[0:3] # Kp gain for (x, y, z)
        Ki_pos = Ki[0:3] # Ki gain for (x, y, z)
        Kd_pos = Kd[0:3] # Kp gain for (x, y, z)

        Kp_orn = Kp[3:6] # Kp gain for (r, p, y)
        Ki_orn = Ki[3:6] # Ki gain for (r, p, y)
        Kd_orn = Kd[3:6] # Kd gain for (r, p, y)

        pos, orn = p.getBasePositionAndOrientation(self.drone)
        euler = p.getEulerFromQuaternion(orn)
        vel, ang_vel = p.getBaseVelocity(self.drone)

        # Log the retrieved position and orientation
        logging.info(f"Position: {pos}, Orientation: {orn}, Euler: {euler}")

        curr_error_pos = self.target_position - np.array(pos)
        curr_error_orn = np.array(p.getEulerFromQuaternion(self.target_orn)) - np.array(euler)

        # PID controller algorithm for attitude control using a antiwindup PID controller
        curr_pitch_error_orn = curr_error_orn[1]
        prev_pitch_error_orn = self.prev_error_orn[1]
        curr_prime_pitch_error_orn = self.prev_prime_pitch_error_orn + curr_pitch_error_orn - prev_pitch_error_orn - self.k1 * self.k2 * self.Ts
        tau_pitch = Kp_orn[1] * curr_pitch_error_orn + Ki_orn[1] * curr_prime_pitch_error_orn + Kd_orn[1] * (curr_pitch_error_orn - prev_pitch_error_orn) / self.Ts

        # PID controller algorithm for roll control using a antiwindup PID controller as before
        curr_roll_error_orn = curr_error_orn[0]
        prev_roll_error_orn = self.prev_error_orn[0]
        curr_prime_roll_error_orn = self.prev_prime_roll_error_orn + curr_roll_error_orn - prev_roll_error_orn - self.k1 * self.k2 * self.Ts
        tau_roll = Kp_orn[0] * curr_roll_error_orn + Ki_orn[0] * curr_prime_roll_error_orn + Kd_orn[0] * (curr_roll_error_orn - prev_roll_error_orn) / self.Ts

        # PD controller algorithm for z control
        errZ = curr_error_pos[2]
        thrust_z = Kp_pos[2] * errZ + Kd_pos[2] * (errZ - self.prev_error_pos[2]) / self.Ts
        tot_thrust_z = thrust_z - self.m * self.g

        saturated_tau_pitch = np.clip(tau_pitch, self.min_torque, self.max_torque)
        saturated_tau_roll = np.clip(tau_roll, self.min_torque, self.max_torque)
        saturated_thrust_z = np.clip(tot_thrust_z, self.min_thrust, self.max_thrust)

        # Calculate the desired motor thrusts using the mixer matrix
        desired_forces = np.array([saturated_thrust_z, saturated_tau_roll, saturated_tau_pitch, 0])
        motor_thrusts = np.linalg.solve(self.mixer_matrix, desired_forces)
        
        p.applyExternalForce(self.drone, -1, [0, 0, saturated_thrust_z], [0, 0, 0], p.WORLD_FRAME)

        # Apply torques for roll, pitch, and yaw control
        p.applyExternalTorque(self.drone, -1, [saturated_tau_roll, saturated_tau_pitch, 0], p.WORLD_FRAME)
        p.stepSimulation()

        self.state = np.hstack((pos, euler))
        reward = -np.linalg.norm(curr_error_pos) - np.linalg.norm(curr_error_orn)
        done_pos = np.linalg.norm(curr_error_pos) < 0.1
        done_orn = np.linalg.norm(curr_error_orn) < 0.1
        done = done_pos and done_orn

        self.prev_error_pos = curr_error_pos
        self.prev_error_orn = curr_error_orn
        self.prev_prime_pitch_error_orn = curr_prime_pitch_error_orn
        self.prev_prime_roll_error_orn = curr_prime_roll_error_orn

        truncated = False  # Set this based on episode length if needed

        # Log the state and other details
        logging.info(f"Step: State: {self.state}, Reward: {reward}, Done: {done}")

        return self.state, reward, done, truncated, {}

    def reset(self, seed=None, options=None):
        """Reset drone to initial position."""
        super().reset(seed=seed)
        p.resetBasePositionAndOrientation(self.drone, [0, 0, 0], [0, 0, 0, 1])
        self.state = np.zeros(6)
        p.stepSimulation()  # Ensure simulation updates in GUI
        info = {}  # Additional info dictionary
        return self.state, info
    
    def render(self, mode="human"):
        """Refresh the PyBullet GUI."""
        p.stepSimulation()  # Ensure simulation updates in GUI

    def close(self):
        p.disconnect()
# Out:
# pybullet build time: Mar 18 2025 08:09:30

# %%
DroneClassicalEnv().reset()
# Out:
# /Users/ortol/miniforge3/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
# Train PPO Agent with detailed logging
from stable_baselines3 import PPO
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

env = DroneClassicalEnv()
env.reset()
print("Environment is ready")
model = PPO("MlpPolicy", env, verbose=1)

try:
    model.learn(total_timesteps=100000)
    model.save("drone_pid_ppo")
except Exception as e:
    logging.error(f"An error occurred: {e}")
# Out:
# Environment is ready
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 8254 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5252         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0021731216 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.6        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.62e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00465     |
# |    std                  | 1            |
# |    value_loss           | 6.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4780         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0015917006 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.6        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.4e+03      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 1            |
# |    value_loss           | 5.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4553         |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0024848056 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.6        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00304     |
# |    std                  | 1            |
# |    value_loss           | 5.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4417         |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0037115538 |
# |    clip_fraction        | 0.00601      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.5        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00458     |
# |    std                  | 0.999        |
# |    value_loss           | 5.57e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4337        |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003150944 |
# |    clip_fraction        | 0.00337     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.48e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00339    |
# |    std                  | 0.998       |
# |    value_loss           | 5.42e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4275         |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0059327553 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.5        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.4e+03      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00586     |
# |    std                  | 0.999        |
# |    value_loss           | 5.27e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4235         |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0071701934 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.5        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00636     |
# |    std                  | 1            |
# |    value_loss           | 5.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4224         |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057372665 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.5        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0045      |
# |    std                  | 1            |
# |    value_loss           | 4.97e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4213        |
# |    iterations           | 10          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009195325 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00832    |
# |    std                  | 0.997       |
# |    value_loss           | 4.83e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 4200       |
# |    iterations           | 11         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00778463 |
# |    clip_fraction        | 0.0413     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25.5      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.15e+03   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0069    |
# |    std                  | 0.995      |
# |    value_loss           | 4.68e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4195        |
# |    iterations           | 12          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009156305 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.4       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00866    |
# |    std                  | 0.994       |
# |    value_loss           | 4.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4189        |
# |    iterations           | 13          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008407533 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2e+03       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00729    |
# |    std                  | 0.992       |
# |    value_loss           | 4.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4185        |
# |    iterations           | 14          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007638762 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00568    |
# |    std                  | 0.992       |
# |    value_loss           | 4.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4181        |
# |    iterations           | 15          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008201854 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.4       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00639    |
# |    std                  | 0.994       |
# |    value_loss           | 4.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4167        |
# |    iterations           | 16          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005722099 |
# |    clip_fraction        | 0.0179      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e+03     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00409    |
# |    std                  | 0.993       |
# |    value_loss           | 4e+03       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4158         |
# |    iterations           | 17           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0061451066 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -25.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.72e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00421     |
# |    std                  | 0.991        |
# |    value_loss           | 3.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4147        |
# |    iterations           | 18          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007281661 |
# |    clip_fraction        | 0.0286      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7e+03     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00487    |
# |    std                  | 0.992       |
# |    value_loss           | 3.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4141        |
# |    iterations           | 19          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009072122 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.4       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00752    |
# |    std                  | 0.988       |
# |    value_loss           | 3.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4129        |
# |    iterations           | 20          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010080526 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 0.983       |
# |    value_loss           | 3.49e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 4124       |
# |    iterations           | 21         |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01153001 |
# |    clip_fraction        | 0.0814     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25.2      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.49e+03   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0091    |
# |    std                  | 0.982      |
# |    value_loss           | 3.36e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4115        |
# |    iterations           | 22          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007531668 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00433    |
# |    std                  | 0.979       |
# |    value_loss           | 3.24e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 4116       |
# |    iterations           | 23         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00867768 |
# |    clip_fraction        | 0.0531     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25.1      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.41e+03   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0064    |
# |    std                  | 0.978      |
# |    value_loss           | 3.13e+03   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 4117       |
# |    iterations           | 24         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01263299 |
# |    clip_fraction        | 0.093      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25.1      |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35e+03   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00709   |
# |    std                  | 0.971      |
# |    value_loss           | 3.01e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4118        |
# |    iterations           | 25          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012028613 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25         |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00883    |
# |    std                  | 0.971       |
# |    value_loss           | 2.9e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4111        |
# |    iterations           | 26          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011382684 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00876    |
# |    std                  | 0.966       |
# |    value_loss           | 2.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4108        |
# |    iterations           | 27          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010533806 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+03     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00631    |
# |    std                  | 0.964       |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4106        |
# |    iterations           | 28          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010861942 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00819    |
# |    std                  | 0.962       |
# |    value_loss           | 2.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4103        |
# |    iterations           | 29          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011463006 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00673    |
# |    std                  | 0.961       |
# |    value_loss           | 2.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4093        |
# |    iterations           | 30          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009962925 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00694    |
# |    std                  | 0.959       |
# |    value_loss           | 2.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4094        |
# |    iterations           | 31          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010882738 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 998         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0067     |
# |    std                  | 0.955       |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4092        |
# |    iterations           | 32          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009624998 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 942         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00738    |
# |    std                  | 0.959       |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4095        |
# |    iterations           | 33          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009754574 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 909         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00709    |
# |    std                  | 0.958       |
# |    value_loss           | 2.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4096        |
# |    iterations           | 34          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009415674 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 851         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0069     |
# |    std                  | 0.953       |
# |    value_loss           | 1.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4099        |
# |    iterations           | 35          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009895233 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 819         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.953       |
# |    value_loss           | 1.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4102        |
# |    iterations           | 36          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009063212 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 780         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0076     |
# |    std                  | 0.955       |
# |    value_loss           | 1.8e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4103        |
# |    iterations           | 37          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009563955 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 730         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00655    |
# |    std                  | 0.954       |
# |    value_loss           | 1.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4105        |
# |    iterations           | 38          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010735897 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.6       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 694         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0085     |
# |    std                  | 0.952       |
# |    value_loss           | 1.62e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4105        |
# |    iterations           | 39          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008388992 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 648         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00671    |
# |    std                  | 0.947       |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4106         |
# |    iterations           | 40           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0109028425 |
# |    clip_fraction        | 0.0829       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -24.5        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 617          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00766     |
# |    std                  | 0.949        |
# |    value_loss           | 1.46e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4108        |
# |    iterations           | 41          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011189928 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 579         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00775    |
# |    std                  | 0.945       |
# |    value_loss           | 1.38e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 4109       |
# |    iterations           | 42         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01260362 |
# |    clip_fraction        | 0.0958     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.4      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 547        |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0089    |
# |    std                  | 0.942      |
# |    value_loss           | 1.31e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4110        |
# |    iterations           | 43          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012480174 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 505         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00801    |
# |    std                  | 0.94        |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4110        |
# |    iterations           | 44          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011600268 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 482         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00669    |
# |    std                  | 0.939       |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4109        |
# |    iterations           | 45          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011472727 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 446         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00655    |
# |    std                  | 0.937       |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4107        |
# |    iterations           | 46          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.013964399 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 418         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00697    |
# |    std                  | 0.936       |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4107        |
# |    iterations           | 47          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008559244 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 386         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.935       |
# |    value_loss           | 957         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4106        |
# |    iterations           | 48          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012892494 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 357         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00672    |
# |    std                  | 0.928       |
# |    value_loss           | 893         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4106        |
# |    iterations           | 49          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011179421 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 334         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00724    |
# |    std                  | 0.924       |
# |    value_loss           | 832         |
# -----------------------------------------

# %%
from stable_baselines3 import PPO
import time
import logging
import numpy as np

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

# Load the trained model
model = PPO.load("drone_pid_ppo")

# Create environment
env = DroneClassicalEnv()
#env.reset()

# Run simulation using the trained model
obs, _ = env.reset()  # Unpack the observation and info
for step in range(1000):  # Simulate for 1000 steps
    action, _states = model.predict(np.array(obs))  # Use the trained model to get actions
    obs, reward, done, info, _ = env.step(action)  # Apply the action
    
    # Log the step details
    logging.info(f"Step: {step}, Action: {action}, Reward: {reward}, Done: {done}, States: {obs}")
    
    env.render()  # Show drone movement
    time.sleep(0.1)
# Out:
# 2025-03-23 22:04:37,825 - Position: (0.0, 0.0, -0.0001701388888888889), Orientation: (0.0, 0.0, 0.0, 1.0), Euler: (0.0, -0.0, 0.0)
# 2025-03-23 22:04:37,825 - Step: State: [ 0.          0.         -0.00017014  0.         -0.          0.        ], Reward: -5.000170138888889, Done: False
# 2025-03-23 22:04:37,826 - Step: 0, Action: [0.         0.         0.5321883  1.0826473  1.8320225  0.
#  0.01793964 0.         0.         0.53887117 0.8967309  0.
#  0.         0.         0.9463935  0.         0.         0.70865893], Reward: -5.000170138888889, Done: False, States: [ 0.          0.         -0.00017014  0.         -0.          0.        ]
# Version = 4.1 Metal - 89.3
# Vendor = Apple
# Renderer = Apple M3
# b3Printf: Selected demo: Physics Server
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# MotionThreadFunc thread started
# 2025-03-23 22:04:38,032 - Position: (-1.0668818810654268e-26, -2.6038328505259013e-27, 0.02944930429020311), Orientation: (-5.932035973923189e-09, -9.871450286691841e-09, 0.0, 0.9999999999999999), Euler: (-1.186407194784638e-08, -1.974290057338368e-08, 1.171155964309008e-16)
# 2025-03-23 22:04:38,033 - Step: State: [-1.06688188e-26 -2.60383285e-27  2.94493043e-02 -1.18640719e-08
#  -1.97429006e-08  1.17115596e-16], Reward: -4.9705507187432145, Done: False
# 2025-03-23 22:04:38,033 - Step: 1, Action: [0.05725899 0.         0.3651412  0.53797364 0.         0.
#  0.66708994 0.90343827 0.         0.43163177 1.0420353  0.05134857
#  1.370273   0.5618065  0.426081   1.7432168  0.         0.17470393], Reward: -4.9705507187432145, Done: False, States: [-1.06688188e-26 -2.60383285e-27  2.94493043e-02 -1.18640719e-08
#  -1.97429006e-08  1.17115596e-16]
# 2025-03-23 22:04:38,227 - Position: (-2.7922601450051844e-26, -1.8289320772428062e-26, 0.05581837216798404), Orientation: (-1.90757738036082e-08, -4.26589630722814e-08, -1.9810672452598454e-18, 0.9999999999999989), Euler: (-3.815154760721651e-08, -8.531792614456281e-08, 1.6235433260361165e-15)
# 2025-03-23 22:04:38,228 - Step: State: [-2.79226015e-26 -1.82893208e-26  5.58183722e-02 -3.81515476e-08
#  -8.53179261e-08  1.62354333e-15], Reward: -4.944181721291574, Done: False
# 2025-03-23 22:04:38,228 - Step: 2, Action: [0.         2.4416933  0.         1.2580426  0.         0.
#  0.08817779 0.9684156  0.         0.         0.         0.
# 2025-03-23 22:05:00,012 - Step: State: [-3.17353087e-20  3.35228868e-20 -1.37391067e+01 -5.09516517e-04
#  -2.51451420e-04  6.49709613e-08], Reward: -18.73967491555594, Done: False
# 2025-03-23 22:05:00,012 - Step: 121, Action: [0.01373114 1.8072888  0.         0.24351223 0.         0.
#  0.6463346  0.         0.         0.         0.6592426  0.
#  0.         0.         0.         0.         0.         0.        ], Reward: -18.73967491555594, Done: False, States: [-3.17353087e-20  3.35228868e-20 -1.37391067e+01 -5.09516517e-04
#  -2.51451420e-04  6.49709613e-08]
# 2025-03-23 22:05:00,193 - Position: (-3.259313660264523e-20, 3.5166503131062193e-20, -13.939412218961479), Orientation: (-0.0002592679822605262, -0.00012780655418160678, 4.56945209913499e-10, 0.9999999582227982), Euler: (-0.000518535983152226, -0.00025561310023101454, 6.718618742122633e-08)
# 2025-03-23 22:05:00,194 - Step: State: [-3.25931366e-20  3.51665031e-20 -1.39394122e+01 -5.18535983e-04
#  -2.55613100e-04  6.71861874e-08], Reward: -18.939990334544515, Done: False
# 2025-03-23 22:05:00,194 - Step: 122, Action: [0.         0.20043258 0.         0.8757072  1.281348   0.
#  0.4081587  0.         0.         0.55446106 0.20034094 0.
#  0.54439104 0.         0.         0.         0.         0.        ], Reward: -18.939990334544515, Done: False, States: [-3.25931366e-20  3.51665031e-20 -1.39394122e+01 -5.18535983e-04
#  -2.55613100e-04  6.71861874e-08]
# 2025-03-23 22:05:00,377 - Position: (-3.336401232319303e-20, 3.69267671754378e-20, -14.1412854848096), Orientation: (-0.0002637105933659183, -0.0001297410391890584, 4.5897204951610105e-10, 0.9999999568119919), Euler: (-0.000527421206280945, -0.00025948206984139326, 6.934611925087281e-08)
# 2025-03-23 22:05:00,377 - Step: State: [-3.33640123e-20  3.69267672e-20 -1.41412855e+01 -5.27421206e-04
#  -2.59482070e-04  6.93461193e-08], Reward: -19.14187328075907, Done: False
# 2025-03-23 22:05:00,377 - Step: 123, Action: [0.3403381  0.         0.28413096 0.47824597 0.3281439  0.2872389
#  0.49626568 0.         0.         0.         0.         0.18672544
#  1.3514712  0.90950155 0.         0.         0.         0.        ], Reward: -19.14187328075907, Done: False, States: [-3.33640123e-20  3.69267672e-20 -1.41412855e+01 -5.27421206e-04
#  -2.59482070e-04  6.93461193e-08]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 20
#      18 for step in range(1000):  # Simulate for 1000 steps
#      19     action, _states = model.predict(np.array(obs))  # Use the trained model to get actions
# ---> 20     obs, reward, done, info, _ = env.step(action)  # Apply the action
#      22     # Log the step details
#      23     logging.info(f"Step: {step}, Action: {action}, Reward: {reward}, Done: {done}, States: {obs}")
#
# Cell In[1], line 68, in DroneClassicalEnv.step(self, action)
#      65 Ki_orn = Ki[3:6] # Ki gain for (r, p, y)
#      66 Kd_orn = Kd[3:6] # Kd gain for (r, p, y)
# ---> 68 pos, orn = p.getBasePositionAndOrientation(self.drone)
#      69 euler = p.getEulerFromQuaternion(orn)
#      70 vel, ang_vel = p.getBaseVelocity(self.drone)
#
# KeyboardInterrupt:
